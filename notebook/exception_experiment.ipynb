# %%
import sys
import traceback

# %%
from logger.custom_logger import CustomLogger
logger=CustomLogger().get_Logger(__file__)
class DocumentPortalException(Exception):
    
    def __init__(self, error_message,error_details:sys):

        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Error Message: {self.error_message}
        Traceback: {self.traceback_str}
        """

if __name__=="__main__":
    try:
        a=1/0
    except Exception as e:
        app_raise= DocumentPortalException(e,sys)
        logger.error(DocumentPortalException(e, sys))  
        raise app_raise
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 19
#      18 try:
# ---> 19     a=1/0
#      20 except Exception as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[5], line 23
#      21 app_raise= DocumentPortalException(e,sys)
#      22 logger.error(DocumentPortalException(e, sys))
# ---> 23 raise app_raise
#
# DocumentPortalException:
#         Error in [/var/folders/n_/qtctj2rj0_vcqffng0qn1z980000gn/T/ipykernel_4322/1838555907.py] at line [19]
#         Error Message: division by zero
#         Traceback: Traceback (most recent call last):
#   File "/var/folders/n_/qtctj2rj0_vcqffng0qn1z980000gn/T/ipykernel_4322/1838555907.py", line 19, in <module>
#     a=1/0
# ZeroDivisionError: division by zero
